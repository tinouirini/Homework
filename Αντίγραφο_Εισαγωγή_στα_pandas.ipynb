# %% [markdown]
# <a href="https://colab.research.google.com/github/tinouirini/Homework/blob/main/%CE%91%CE%BD%CF%84%CE%AF%CE%B3%CF%81%CE%B1%CF%86%CE%BF_%CE%95%CE%B9%CF%83%CE%B1%CE%B3%CF%89%CE%B3%CE%B7%CC%81_%CF%83%CF%84%CE%B1_pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Εισαγωγή στα pandas
#
# Σήμερα θα μάθουμε να εισάγουμε, επεξεργαζόμαστε και αποθηκεύουμε πλαίσια δεδομένων, που από εδώ και στο εξής θα τα αποκαλούμε Dataframes και για συντομία df.
#
# Για αρχή πρέπει να καλέσουμε τη βιβλιοθήκη pandas για να μπορέσουμε να δουλέψουμε με Dataframes.
#
# Ξεκινάμε λοιπόν εισάγωντας ένα αρχείο comma-separated values (CSV).

# %%
import pandas as pd # ορίζω την βιβλιοθήκη panda ως pd για να υπαρχει μέσα στον κώδικα.
#csv : αρχείο σαν excel- πίνακας που περιέχει τιμές

# %%
df = pd.read_csv("https://raw.githubusercontent.com/datajour-gr/Data-Journalism-bachelor/main/week3/countries.csv")

# %%
df
#αρχίζει απο το 0 σαν τις λίστες.
# 188 rows ειναι το lenght , δείχνουν το index
#ζητώντας το crv δείχνει τα 5 πρώτα και τα 5 τελευταία.
# Out:
#                  country   continent  gdp_per_capita  life_expectancy  \
# 0            Afghanistan        Asia             663           54.863
# 1                Albania      Europe            4195           74.200
# 2                Algeria      Africa            5098           68.963
# 3                 Angola      Africa            2446           45.234
# 4    Antigua and Barbuda  N. America           12738           73.544
# ..                   ...         ...             ...              ...
# 183              Vietnam        Asia            1577           73.777
# 184   West Bank and Gaza        Asia            7586           70.929
# 185          Yemen, Rep.        Asia            2217           60.404
# 186               Zambia      Africa            1035           41.802
# 187             Zimbabwe      Africa             745           43.976
#
#      population
# 0      22856302
# 1       3071856
# 2      30533827
# 3      13926373
# 4         77656
# ..          ...
# 183    78758010
# 184     3198560
# 185    17723186
# 186    10201562
# 187    12509477
#
# [188 rows x 5 columns]

# %% [markdown]
# Με το .head( ) βλέπουμε τα πρώτα 5 κελιά και με το .tail( ) τα τελευταία. Μπορούμε να αλλάξουμε τον αριθμό των κελιών που εμφανίζονται
# βάζοντας τον αριθμό που θέλουμε μέσα στις παρενθέσεις.

# %%
df.head() #φέρνει τα 5 πρωτα γραφόντας head με κενή παρενθεση
# Out:
#                country   continent  gdp_per_capita  life_expectancy  \
# 0          Afghanistan        Asia             663           54.863
# 1              Albania      Europe            4195           74.200
# 2              Algeria      Africa            5098           68.963
# 3               Angola      Africa            2446           45.234
# 4  Antigua and Barbuda  N. America           12738           73.544
#
#    population
# 0    22856302
# 1     3071856
# 2    30533827
# 3    13926373
# 4       77656

# %%
df.tail() #φέρνει τα 5 τελευταία.
# Out:
#                 country continent  gdp_per_capita  life_expectancy  population
# 183             Vietnam      Asia            1577           73.777    78758010
# 184  West Bank and Gaza      Asia            7586           70.929     3198560
# 185         Yemen, Rep.      Asia            2217           60.404    17723186
# 186              Zambia    Africa            1035           41.802    10201562
# 187            Zimbabwe    Africa             745           43.976    12509477

# %%
df.head(8) # φέρνει απο αρχή(head) μέχρι το 8 , όχι το 8.
# Out:
#                country   continent  gdp_per_capita  life_expectancy  \
# 0          Afghanistan        Asia             663           54.863
# 1              Albania      Europe            4195           74.200
# 2              Algeria      Africa            5098           68.963
# 3               Angola      Africa            2446           45.234
# 4  Antigua and Barbuda  N. America           12738           73.544
# 5            Argentina  S. America           10571           73.822
# 6              Armenia      Europe            2114           71.494
# 7            Australia     Oceania           29241           79.930
#
#    population
# 0    22856302
# 1     3071856
# 2    30533827
# 3    13926373
# 4       77656
# 5    36930709
# 6     3076098
# 7    19164351

# %% [markdown]
# Η πρώτη στήλη στα αριστερά λέγεται index

# %%
df.tail(10) #φέρνει τα τελυεταία 10 (tail)
# Out:
#                 country   continent  gdp_per_capita  life_expectancy  \
# 178       United States  N. America           39758           76.800
# 179             Uruguay  S. America            9092           74.777
# 180          Uzbekistan        Asia            1635           66.999
# 181             Vanuatu     Oceania            3762           67.438
# 182           Venezuela  S. America            9434           72.432
# 183             Vietnam        Asia            1577           73.777
# 184  West Bank and Gaza        Asia            7586           70.929
# 185         Yemen, Rep.        Asia            2217           60.404
# 186              Zambia      Africa            1035           41.802
# 187            Zimbabwe      Africa             745           43.976
#
#      population
# 178   282496310
# 179     3319066
# 180    24775610
# 181      185074
# 182    24348304
# 183    78758010
# 184     3198560
# 185    17723186
# 186    10201562
# 187    12509477

# %% [markdown]
# Πάμε να δούμε τι στήλες έχουμε στα δεδομένα μας.

# %%
df.columns # μας δείχνει τα ονόματα των στηλών. #είναι λίστα
# Out:
# Index(['country', 'continent', 'gdp_per_capita', 'life_expectancy',
#        'population'],
#       dtype='object')

# %% [markdown]
# Ας δούμε τώρα και τι τύπος είναι η κάθε στήλη.

# %%
df.dtypes #με την εντολή dtypes μας δείχνει τι τύπος δεδομένων έιναι κάθε στήλη
#object σημαίνει συμβολοσειρά (είναι σαν string)
# Out:
# country             object
# continent           object
# gdp_per_capita       int64
# life_expectancy    float64
# population           int64
# dtype: object

# %% [markdown]
# Ας τα ταξινομήσουμε σύμφωνα με τον πληθυσμό κάθε χώρας.

# %%
df.sort_values(by='population', ascending = False).head()
#ή df.sort_values(by='population', ascending = True).tail()
# sort_values(by=" ",ascending = true  ή  false ) ---> εντολή για ταξινόμηση
# άμα δεν γράψω ascending το παίρνει ως true δηλαδή αύξουσα! αμά θέλω αυξουσά δεν το γράφω δηλαδή.
#true = αύξουσα σειρά , false = φθίνουσα σειρά
# .head = και δωσμου τα 5 πρώτα να τα δώ
# gdp_per_capita = κατα κεφαλήν εισόδημα.
# Out:
#            country   continent  gdp_per_capita  life_expectancy  population
# 34           China        Asia            3407           72.124  1269116737
# 75           India        Asia            1648           62.129  1053898107
# 178  United States  N. America           39758           76.800   282496310
# 76       Indonesia        Asia            2714           67.289   213395411
# 22          Brazil  S. America            8056           70.261   174425387

# %%
df["population"].head()
# df [""] μου δείνει μόνο τη μία στήλη
# Out:
# 0    22856302
# 1     3071856
# 2    30533827
# 3    13926373
# 4       77656
# Name: population, dtype: int64

# %%
df["population"].median()
#μου δείνει τη μέση τιμή (βάζω τις τιμές σε αυξουσά σειρά και παίρνω την τιμή που είναι στη μέση)
# Out:
# 6888970.5

# %%
df['population'].mean()
#μου δείνει τον μέσο όρο
# Out:
# 32526821.05319149

# %%
df["population"].sum()
#συνολική τιμή
# Out:
# 6115042358

# %%
df["population"].std()
#μέση απόκλιση
# Out:
# 123795162.37011255

# %%
df["population"].max()
#μέγιστη τιμή της στήλης
# Out:
# 1269116737

# %% [markdown]
# Περιγραφή όλων των στηλών

# %%
df["population"].describe()
# Out:
# count    1.880000e+02
# mean     3.252682e+07
# std      1.237952e+08
# min      5.619600e+04
# 25%      2.003170e+06
# 50%      6.888970e+06
# 75%      2.218517e+07
# max      1.269117e+09
# Name: population, dtype: float64

# %% [markdown]
# Δεν φαίνονται και τόσο ξεκάθαρα, ας τα δούμε σαν ακέραιους αριθμούς!

# %%
df["population"].describe().astype(int)
# Out:
# count           188
# mean       32526821
# std       123795162
# min           56196
# 25%         2003169
# 50%         6888970
# 75%        22185170
# max      1269116737
# Name: population, dtype: int64

# %%
df['continent'].value_counts().head()
#to value_counts metraei poses fores emfanizetai kati
# Out:
# continent
# Africa        54
# Asia          48
# Europe        42
# N. America    22
# S. America    12
# Name: count, dtype: int64

# %%
df['continent'].describe()
# Out:
# count        188
# unique         6
# top       Africa
# freq          54
# Name: continent, dtype: object

# %% [markdown]
# Πάμε να φτιάξουμε το πρώτο μας γράφημα!

# %%
df['continent'].value_counts().plot

# %% [markdown]
# Κάτι προσπαθεί να κάνει, αλλά φαίνεται ότι κάτι λείπει...

# %% [markdown]
# Χρειαζόμαστε μια βιβλιοθήκη γραφικών.
# Ας φέρουμε την matplotlib
# Βάζοντας μπορστά το % αναθέτουμε την βιβλιοθήκη από δω και κάτω.

# %%
# %matplotlib inline

# %%
df['continent'].value_counts().plot()
# Out:
# <Axes: xlabel='continent'>

# %%
df['continent'].value_counts().sort_values(ascending=True).plot(kind='barh')
# Out:
# <Axes: ylabel='continent'>

# %%
df['continent'].value_counts().plot(kind='barh') #barh είναι το οριζόντιο γράφημα
# Out:
# <Axes: ylabel='continent'>

# %%
df.plot(kind='scatter', x='gdp_per_capita', y='life_expectancy')
# Out:
# <Axes: xlabel='gdp_per_capita', ylabel='life_expectancy'>

# %% [markdown]
# Ο τρόπος που αναλύουμε τα δεδομένα είναι ο εξής:
# Πρώτα κάνουμε μια υπόθεση και μετά προχωρούμε ρωτώντας τα δεδομένα μας τις σχετικές ερωτήσεις. Δεν κάνουμε απλά αναζήτηση των δεδομένων!
# Ας ρωτήσουμε πχ. ποια είναι η μεγαλύτερη χώρα, ποια έχει το μεγαλύτερο ΑΕΠ (Ακαθάριστο Εγχώριο Προϊόν (Gross domestic product - GDP)
#
# Τι είναι ?
# - Ακαθάριστο Εγχώριο Προϊόν είναι το σύνολο των προϊόντων, υλικών και άυλων, που παράχθηκαν μέσα στην επικράτεια μιας χώρας σε διάστημα ενός έτους, εκφρασμένο σε χρηματικές μονάδες, ακόμα και αν μέρος αυτού παράχθηκε από παραγωγικές μονάδες που ανήκουν σε κατοίκους του εξωτερικού.

# %% [markdown]
# ## Πρέπει να βρούμε:
#
# με ποια στήλη να κάνουμε το γκρουπάρισμα (group by)
#
# από ποια στήλη θέλουμε πληροφορίες
#
# τι είδους πληροφορίες θέλουμε από αυτή την στήλη
#
# *Οι παρενθέσεις είναι για το groupby και οι αγκύλες για την στήλη από την οποία θέλουμε πληροφορίες, το groupby μπαίνει στην αρχή για να φιλτράρει

# %%
df.groupby("continent")["gdp_per_capita"].mean() #ομαδοποιει τα γεγονοτα βαση την στηλη κοντινεντ - groupby
# Out:
# continent
# Africa         2621.648148
# Asia          11106.437500
# Europe        18647.880952
# N. America    11665.681818
# Oceania        8038.400000
# S. America     6738.583333
# Name: gdp_per_capita, dtype: float64

# %%
df.groupby('continent')[['country', 'population']].max() # οταν ειναι . ειναι ενα function , τα φαν εχουν παρενθεση και μεσα μπαινουν παραμετροι.Αν δεν βαλεισ παραμετρο υπαρχει μια default τιμη.
#οταν βαζω μια που εχει str οπωσ το country και μια με αριθμουσ population τοτε παιρνει πρωτα το αριθμητικο και το αλλο σαν βοηθητικο
# Out:
#                    country  population
# continent
# Africa            Zimbabwe   123688536
# Asia           Yemen, Rep.  1269116737
# Europe      United Kingdom    82349027
# N. America   United States   282496310
# Oceania            Vanuatu    19164351
# S. America       Venezuela   174425387

# %%
df.groupby('continent')['population'].max() #bazontas dio agkiles pairno morfh dataframa - pinakas -df.groupby('continent')[['population']].max()
# Out:
# continent
# Africa         123688536
# Asia          1269116737
# Europe          82349027
# N. America     282496310
# Oceania         19164351
# S. America     174425387
# Name: population, dtype: int64

# %%
#Πόσες γραμμές και πόσες στήλες έχουμε
df.shape
# Out:
# (188, 5)

# %%
df['new_continent'] = df['continent']

# %%
df.continent.head()
# Out:
# 0          Asia
# 1        Europe
# 2        Africa
# 3        Africa
# 4    N. America
# Name: continent, dtype: object

# %%
df.head()
# Out:
#                country   continent  gdp_per_capita  life_expectancy  \
# 0          Afghanistan        Asia             663           54.863
# 1              Albania      Europe            4195           74.200
# 2              Algeria      Africa            5098           68.963
# 3               Angola      Africa            2446           45.234
# 4  Antigua and Barbuda  N. America           12738           73.544
#
#    population new_continent
# 0    22856302          Asia
# 1     3071856        Europe
# 2    30533827        Africa
# 3    13926373        Africa
# 4       77656    N. America

# %% [markdown]
# Ο τύπος boolean ορίζεται από το πεδίο τιμών {true, false}.
#
# Οι παρακάτω τελεστές παράγουν αποτέλεσμα τύπου boolean:

# %%
#=   Ισότητα
#!= Διάφορο
#<   Μικρότερο
#>   Μεγαλύτερο
#<= Μικρότερο ή ίσο
#>= Μεγαλύτερο ή ίσο

# %% [markdown]
# Πώς ρωτάμε το dataframe, είναι η ήπειρος σου η Ασία?

# %%
df_Asia = df[df['continent'] == 'Asia']

# %%
df_Asia.head()
# Out:
#         country continent  gdp_per_capita  life_expectancy  population  \
# 0   Afghanistan      Asia             663           54.863    22856302
# 11      Bahrain      Asia           22015           74.497      638193
# 12   Bangladesh      Asia            1075           65.309   129592275
# 18       Bhutan      Asia            2922           60.307      571262
# 23       Brunei      Asia           48020           75.927      327036
#
#    new_continent
# 0           Asia
# 11          Asia
# 12          Asia
# 18          Asia
# 23          Asia

# %% [markdown]
# Όταν δείτε απαντήσεις με *True False* τότε έχετε ξεχάσει να βάλετε αγκύλες!

# %%
#df [ ] και μέσα το condition
df[df['continent'] == 'Asia'] #filtrarv to df me bash thn asia.
# Out:
#                   country continent  gdp_per_capita  life_expectancy  \
# 0             Afghanistan      Asia             663           54.863
# 11                Bahrain      Asia           22015           74.497
# 12             Bangladesh      Asia            1075           65.309
# 18                 Bhutan      Asia            2922           60.307
# 23                 Brunei      Asia           48020           75.927
# 27               Cambodia      Asia             982           62.030
# 34                  China      Asia            3407           72.124
# 72       Hong Kong, China      Asia           29972           80.361
# 75                  India      Asia            1648           62.129
# 76              Indonesia      Asia            2714           67.289
# 77                   Iran      Asia            8600           69.611
# 78                   Iraq      Asia            3951           70.845
# 80                 Israel      Asia           22834           78.750
# 83                  Japan      Asia           28559           81.350
# 84                 Jordan      Asia            3664           71.724
# 85             Kazakhstan      Asia            5366           63.513
# 88       Korea, Dem. Rep.      Asia            1689           65.271
# 89            Korea, Rep.      Asia           16995           76.114
# 90                 Kuwait      Asia           36397           73.133
# 91             Kyrgyzstan      Asia            1527           66.232
# 92                   Laos      Asia            1518           61.689
# 94                Lebanon      Asia            5795           74.409
# 100          Macao, China      Asia           22512           77.627
# 104              Malaysia      Asia           10161           72.810
# 105              Maldives      Asia            3433           69.279
# 113              Mongolia      Asia            2017           62.876
# 117               Myanmar      Asia            1034           62.073
# 119                 Nepal      Asia            1054           62.055
# 126                  Oman      Asia           19204           72.139
# 127              Pakistan      Asia            2086           63.854
# 132           Philippines      Asia            2598           66.774
# 135                 Qatar      Asia           60394           76.680
# 137                Russia      Asia            8570           65.380
# 143          Saudi Arabia      Asia           20001           72.401
# 148             Singapore      Asia           36834           78.340
# 156             Sri Lanka      Asia            2997           71.078
# 162                 Syria      Asia            3935           73.316
# 163                Taiwan      Asia           23525           76.020
# 164            Tajikistan      Asia            1001           63.570
# 166              Thailand      Asia            5578           70.921
# 167           Timor-Leste      Asia            2743           59.468
# 172                Turkey      Asia            6803           70.010
# 173          Turkmenistan      Asia            3289           63.925
# 176  United Arab Emirates      Asia           30012           74.163
# 180            Uzbekistan      Asia            1635           66.999
# 183               Vietnam      Asia            1577           73.777
# 184    West Bank and Gaza      Asia            7586           70.929
# 185           Yemen, Rep.      Asia            2217           60.404
#
#      population new_continent
# 0      22856302          Asia
# 11       638193          Asia
# 12    129592275          Asia
# 18       571262          Asia
# 23       327036          Asia
# 27     12446949          Asia
# 34   1269116737          Asia
# 72      6783317          Asia
# 75   1053898107          Asia
# 76    213395411          Asia
# 77     65342319          Asia
# 78     23857458          Asia
# 80      6014953          Asia
# 83    125720310          Asia
# 84      4827096          Asia
# 85     14956694          Asia
# 88     22894095          Asia
# 89     45987624          Asia
# 90      1940786          Asia
# 91      4954850          Asia
# 92      5317060          Asia
# 94      3742329          Asia
# 100      431867          Asia
# 104    23414909          Asia
# 105      273236          Asia
# 113     2411369          Asia
# 117    44957660          Asia
# 119    24400606          Asia
# 126     2264163          Asia
# 127   144522192          Asia
# 132    77309965          Asia
# 135      590957          Asia
# 137   146757517          Asia
# 143    20045276          Asia
# 148     3919300          Asia
# 156    18745084          Asia
# 162    15988534          Asia
# 163    22183000          Asia
# 164     6172807          Asia
# 166    63155029          Asia
# 167      830089          Asia
# 172    63627862          Asia
# 173     4501419          Asia
# 176     3033491          Asia
# 180    24775610          Asia
# 183    78758010          Asia
# 184     3198560          Asia
# 185    17723186          Asia

# %%
df['new_comtinent']=df['continent']
df.head()
#otan thelo 2 sinthikes
df[(df['continent'] == 'Asia') & (df['life_expectancy']>=70)]
df[(df['continent'] == 'Asia') | (df['life_expectancy']>=70)] #an thelo h to ena h to allo , dhl h na einai xores ths asias h na einai pano apo 80
# Out:
#                  country   continent  gdp_per_capita  life_expectancy  \
# 0            Afghanistan        Asia             663           54.863
# 1                Albania      Europe            4195           74.200
# 4    Antigua and Barbuda  N. America           12738           73.544
# 5              Argentina  S. America           10571           73.822
# 6                Armenia      Europe            2114           71.494
# ..                   ...         ...             ...              ...
# 180           Uzbekistan        Asia            1635           66.999
# 182            Venezuela  S. America            9434           72.432
# 183              Vietnam        Asia            1577           73.777
# 184   West Bank and Gaza        Asia            7586           70.929
# 185          Yemen, Rep.        Asia            2217           60.404
#
#      population new_continent   millions           aep new_comtinent
# 0      22856302          Asia  22.856302   15153728226          Asia
# 1       3071856        Europe   3.071856   12886435920        Europe
# 4         77656    N. America   0.077656     989182128    N. America
# 5      36930709    S. America  36.930709  390394524839    S. America
# 6       3076098        Europe   3.076098    6502871172        Europe
# ..          ...           ...        ...           ...           ...
# 180    24775610          Asia  24.775610   40508122350          Asia
# 182    24348304    S. America  24.348304  229701899936    S. America
# 183    78758010          Asia  78.758010  124201381770          Asia
# 184     3198560          Asia   3.198560   24264276160          Asia
# 185    17723186          Asia  17.723186   39292303362          Asia
#
# [118 rows x 9 columns]

# %%
df['gdp_per_capita'].mean() #μεσος ορος
# Out:
# 9977.558510638299

# %% [markdown]
# Είναι το ΑΕΠ μεγαλύτερο από το μέσο όρο?
# Θέλω όλα τα κελιά στα οποία είναι το ΑΕΠ μεγαλύτερο του μέσου όρου και τα θέλω σε μορφή dataframe

# %%
df[df['gdp_per_capita'] > df['gdp_per_capita'].mean()]
#αν γραψω μονο τη συνθηκη παιρνω true false , πρεπει να βαλω μπροστα df και αγκυλη
# Out:
#                   country   continent  gdp_per_capita  life_expectancy  \
# 4     Antigua and Barbuda  N. America           12738        73.544000
# 5               Argentina  S. America           10571        73.822000
# 7               Australia     Oceania           29241        79.930000
# 8                 Austria      Europe           32008        78.330000
# 10                Bahamas  N. America           22728        72.370000
# 11                Bahrain        Asia           22015        74.497000
# 13               Barbados  N. America           14982        73.118000
# 15                Belgium      Europe           29940        77.910000
# 21               Botswana      Africa           10107        50.567000
# 23                 Brunei        Asia           48020        75.927000
# 29                 Canada  N. America           32448        79.410000
# 33                  Chile  S. America           10435        77.010000
# 41                Croatia      Europe           10582        74.798000
# 43                 Cyprus      Europe           22821        78.011000
# 44             Czech Rep.      Europe           16823        75.050000
# 45                Denmark      Europe           31805        76.900000
# 53                Estonia      Europe           11244        70.800000
# 56                Finland      Europe           27171        77.760000
# 57                 France      Europe           28636        79.230000
# 58                  Gabon      Africa           12764        59.744000
# 61                Germany      Europe           29726        78.141275
# 63                 Greece      Europe           20675        78.535000
# 64              Greenland  N. America           33204        67.030000
# 72       Hong Kong, China        Asia           29972        80.361000
# 73                Hungary      Europe           13592        71.860000
# 74                Iceland      Europe           31092        79.720000
# 79                Ireland      Europe           30827        76.660000
# 80                 Israel        Asia           22834        78.750000
# 81                  Italy      Europe           27160        79.730000
# 83                  Japan        Asia           28559        81.350000
# 89            Korea, Rep.        Asia           16995        76.114000
# 90                 Kuwait        Asia           36397        73.133000
# 99             Luxembourg      Europe           63924        77.820000
# 100          Macao, China        Asia           22512        77.627000
# 104              Malaysia        Asia           10161        72.810000
# 107                 Malta      Europe           20276        77.364000
# 110                Mexico  N. America           10894        74.380000
# 120           Netherlands      Europe           33000        78.240000
# 121           New Zealand     Oceania           21895        78.900000
# 125                Norway      Europe           43174        78.760000
# 126                  Oman        Asia           19204        72.139000
# 133                Poland      Europe           11680        73.910000
# 134              Portugal      Europe           19609        76.840000
# 135                 Qatar        Asia           60394        76.680000
# 143          Saudi Arabia        Asia           20001        72.401000
# 146            Seychelles      Africa           15230        71.771000
# 148             Singapore        Asia           36834        78.340000
# 149       Slovak Republic      Europe           12689        73.190000
# 150              Slovenia      Europe           19399        76.110000
# 155                 Spain      Europe           23410        79.340000
# 160                Sweden      Europe           28640        79.840000
# 161           Switzerland      Europe           34386        79.990000
# 163                Taiwan        Asia           23525        76.020000
# 170   Trinidad and Tobago  N. America           10496        68.533000
# 176  United Arab Emirates        Asia           30012        74.163000
# 177        United Kingdom      Europe           28644        78.040000
# 178         United States  N. America           39758        76.800000
#
#      population new_continent
# 4         77656    N. America
# 5      36930709    S. America
# 7      19164351       Oceania
# 8       8004712        Europe
# 10       297651    N. America
# 11       638193          Asia
# 13       267511    N. America
# 15     10175684        Europe
# 21      1757925        Africa
# 23       327036          Asia
# 29     30667365    N. America
# 33     15419820    S. America
# 41      4505533        Europe
# 43       943294        Europe
# 44     10242890        Europe
# 45      5339501        Europe
# 53      1370749        Europe
# 56      5173370        Europe
# 57     59047795        Europe
# 58      1235274        Africa
# 61     82349027        Europe
# 63     10986883        Europe
# 64        56196    N. America
# 72      6783317          Asia
# 73     10210545        Europe
# 74       281210        Europe
# 79      3803780        Europe
# 80      6014953          Asia
# 81     56986329        Europe
# 83    125720310          Asia
# 89     45987624          Asia
# 90      1940786          Asia
# 99       435491        Europe
# 100      431867          Asia
# 104    23414909          Asia
# 107      397420        Europe
# 110    99959594    N. America
# 120    15862825        Europe
# 121     3858032       Oceania
# 125     4490859        Europe
# 126     2264163          Asia
# 133    38302444        Europe
# 134    10336209        Europe
# 135      590957          Asia
# 143    20045276          Asia
# 146       78685        Africa
# 148     3919300          Asia
# 149     5404845        Europe
# 150     1985406        Europe
# 155    40288457        Europe
# 160     8860153        Europe
# 161     7167908        Europe
# 163    22183000          Asia
# 170     1292058    N. America
# 176     3033491          Asia
# 177    58874117        Europe
# 178   282496310    N. America

# %%
df[(df['continent'] == 'Asia') & (df['gdp_per_capita'] > df['gdp_per_capita'].mean())].head()
# Out:
#              country continent  gdp_per_capita  life_expectancy  population  \
# 11           Bahrain      Asia           22015           74.497      638193
# 23            Brunei      Asia           48020           75.927      327036
# 72  Hong Kong, China      Asia           29972           80.361     6783317
# 80            Israel      Asia           22834           78.750     6014953
# 83             Japan      Asia           28559           81.350   125720310
#
#    new_continent
# 11          Asia
# 23          Asia
# 72          Asia
# 80          Asia
# 83          Asia

# %%
df[(df['continent'] == 'Africa') & (df['life_expectancy'] < 40)]
# Out:
#           country continent  gdp_per_capita  life_expectancy  population  \
# 147  Sierra Leone    Africa             517           38.123     4143115
#
#     new_continent
# 147        Africa

# %%
# σε εκατομμύρια
df['population'] / 1000000
# Out:
# 0      22.856302
# 1       3.071856
# 2      30.533827
# 3      13.926373
# 4       0.077656
#          ...
# 183    78.758010
# 184     3.198560
# 185    17.723186
# 186    10.201562
# 187    12.509477
# Name: population, Length: 188, dtype: float64

# %% [markdown]
# Θέλουμε να σώσουμε το αποτέλεσμα σε μια νέα στήλη και να είναι σε
#
# ---
#
# εκατομμύρια

# %%
df['millions'] = df['population'] /1000000
df.head()
# Out:
#                country   continent  gdp_per_capita  life_expectancy  \
# 0          Afghanistan        Asia             663           54.863
# 1              Albania      Europe            4195           74.200
# 2              Algeria      Africa            5098           68.963
# 3               Angola      Africa            2446           45.234
# 4  Antigua and Barbuda  N. America           12738           73.544
#
#    population new_continent   millions
# 0    22856302          Asia  22.856302
# 1     3071856        Europe   3.071856
# 2    30533827        Africa  30.533827
# 3    13926373        Africa  13.926373
# 4       77656    N. America   0.077656

# %% [markdown]
# Ας κάνουμε μια νέα στήλη με το ΑΕΠ, αλλά όχι κατά κεφαλήν

# %%
df['aep'] = df['gdp_per_capita'] * df['population']
#df['aep'] = df['gdp_per_capita'] * df['population'].head() #θα υπολογιζε μονο τα 5 πρωτα ετσι λαθοσ αρα το γραφω μετα
df.head()
# Out:
#                country   continent  gdp_per_capita  life_expectancy  \
# 0          Afghanistan        Asia             663           54.863
# 1              Albania      Europe            4195           74.200
# 2              Algeria      Africa            5098           68.963
# 3               Angola      Africa            2446           45.234
# 4  Antigua and Barbuda  N. America           12738           73.544
#
#    population new_continent   millions           aep
# 0    22856302          Asia  22.856302   15153728226
# 1     3071856        Europe   3.071856   12886435920
# 2    30533827        Africa  30.533827  155661450046
# 3    13926373        Africa  13.926373   34063908358
# 4       77656    N. America   0.077656     989182128

# %% [markdown]
# 'Οπως βλέπετε μπορούμε να εκτελέσουμε εντολές και χωρίς τα "" εκτός και αν έχουν κενά τα ονόματα των στηλών!

# %%
df.gdp_per_capita * df.population
# Out:
# 0       15153728226
# 1       12886435920
# 2      155661450046
# 3       34063908358
# 4         989182128
#            ...
# 183    124201381770
# 184     24264276160
# 185     39292303362
# 186     10558616670
# 187      9319560365
# Length: 188, dtype: int64

# %%
df_new2 = df[['continent', 'population', 'aep']]

# %%
df_new2.head()
# Out:
#     continent  population           aep
# 0        Asia    22856302   15153728226
# 1      Europe     3071856   12886435920
# 2      Africa    30533827  155661450046
# 3      Africa    13926373   34063908358
# 4  N. America       77656     989182128
